# %%
import Renderer
import importlib
import Main
importlib.reload(Renderer)
importlib.reload(Main)
from Renderer import F1ReplayWindow

ret = Main.main(2021, 7)
track, circuit_info = ret[0], ret[1]
print(len(track))
win = F1ReplayWindow('Test', track, circuit_info)
win.run()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (191.88 MB) C:\Users\samue\AppData\Local\Temp\fastf1
# core           INFO 	Loading data for French Grand Prix - Qualifying [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']
# 411
# Exception ignored on calling ctypes callback function: <function Win32Window._get_window_proc.<locals>.f at 0x0000021FFEC6F9C0>
# Traceback (most recent call last):
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 871, in f
#     result = event_handler(msg, wParam, lParam)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 1246, in _event_size
#     self.dispatch_event('_on_internal_resize', self._width, self._height)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 371, in dispatch_event
#     if getattr(self, event_type)(*args):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 876, in _on_internal_resize
#     self.dispatch_event('on_resize', w, h)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 364, in dispatch_event
#     if handler(*args):
#        ^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 881, in _on_resize
#     self.viewport = (0, 0, width, height)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 1001, in viewport
#     self._ctx.viewport = new_viewport
#     ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\context.py", line 382, in viewport
#     self._default_camera.use()
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 135, in use
#     self.viewport = LBWH(*self._ctx.viewport)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 53, in viewport
#     self._projection_matrix = Mat4.orthogonal_projection(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\math.py", line 1133, in orthogonal_projection
#     s_y = 2.0 / height
#           ~~~~^~~~~~~~
# ZeroDivisionError: float division by zero
# Exception ignored on calling ctypes callback function: <function Win32Window._get_window_proc.<locals>.f at 0x0000021FFEC6F9C0>
# Traceback (most recent call last):
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 871, in f
#     result = event_handler(msg, wParam, lParam)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 1246, in _event_size
#     self.dispatch_event('_on_internal_resize', self._width, self._height)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 371, in dispatch_event
#     if getattr(self, event_type)(*args):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 876, in _on_internal_resize
#     self.dispatch_event('on_resize', w, h)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 364, in dispatch_event
#     if handler(*args):
#        ^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 881, in _on_resize
#     self.viewport = (0, 0, width, height)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 1001, in viewport
#     self._ctx.viewport = new_viewport
#     ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\context.py", line 382, in viewport
#     self._default_camera.use()
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 135, in use
#     self.viewport = LBWH(*self._ctx.viewport)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 53, in viewport
#     self._projection_matrix = Mat4.orthogonal_projection(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\math.py", line 1133, in orthogonal_projection
#     s_y = 2.0 / height
#           ~~~~^~~~~~~~
# ZeroDivisionError: float division by zero
# Exception ignored on calling ctypes callback function: <function Win32Window._get_window_proc.<locals>.f at 0x0000021FFEC6F9C0>
# Traceback (most recent call last):
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 871, in f
#     result = event_handler(msg, wParam, lParam)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\win32\__init__.py", line 1246, in _event_size
#     self.dispatch_event('_on_internal_resize', self._width, self._height)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 371, in dispatch_event
#     if getattr(self, event_type)(*args):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 876, in _on_internal_resize
#     self.dispatch_event('on_resize', w, h)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\window\__init__.py", line 685, in dispatch_event
#     super().dispatch_event(*args)
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\event.py", line 364, in dispatch_event
#     if handler(*args):
#        ^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 881, in _on_resize
#     self.viewport = (0, 0, width, height)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\application.py", line 1001, in viewport
#     self._ctx.viewport = new_viewport
#     ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\context.py", line 382, in viewport
#     self._default_camera.use()
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 135, in use
#     self.viewport = LBWH(*self._ctx.viewport)
#     ^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\arcade\camera\default.py", line 53, in viewport
#     self._projection_matrix = Mat4.orthogonal_projection(
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\samue\OneDrive - DVHE\Python\Formula1\formula1\Lib\site-packages\pyglet\math.py", line 1133, in orthogonal_projection
#     s_y = 2.0 / height
#           ~~~~^~~~~~~~
# ZeroDivisionError: float division by zero

# %%
import Renderer
import importlib
import Main
importlib.reload(Renderer)
importlib.reload(Main)
from Renderer import F1ReplayWindow

ret = Main.main(2021, 7)
track, circuit_info = ret[0], ret[1]
print(track.columns)
# Out:
# core           INFO 	Loading data for French Grand Prix - Qualifying [v3.7.0]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['33', '44', '77', '11', '55', '10', '16', '4', '14', '3', '31', '5', '99', '63', '47', '6', '7', '9', '18', '22']
# Index(['X', 'Y'], dtype='object')
